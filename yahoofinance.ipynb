# %%
import yfinance as yf
import pandas as pd
from concurrent.futures import ThreadPoolExecutor, ProcessPoolExecutor

# %%
tickerlist = pd.read_csv("data/company_tickers_filtered.csv")
# first = tickerlist.iloc[0].ticker
# cik = str(tickerlist["cik_str"].iloc[0]).zfill(10)

# dat = yf.Ticker(first)
# history = pd.DataFrame(dat.history(period= "max"))

# history.to_csv(f'data/stockprice/CIK{cik}.csv')

# %%
def saveHistory(row):
    ticker = row["ticker"]
    dat = yf.Ticker(ticker)
    history = pd.DataFrame(dat.history(period="max"))
    history.to_csv(f"data/stockprice/{ticker}.csv")

# %%
#
# Out:
# [*********************100%***********************]  10 of 10 completed
# [******************************140%*********************************]  14 of 10 completed
# Price      Close                                                       \
# Ticker       AHH  APLMW      ARTNB        BWA         CG CLRCF    CLW
# Date
# 1990-10-01   NaN    NaN        NaN        NaN        NaN   NaN    NaN
# 1990-10-02   NaN    NaN        NaN        NaN        NaN   NaN    NaN
# 1990-10-03   NaN    NaN        NaN        NaN        NaN   NaN    NaN
# 1990-10-04   NaN    NaN        NaN        NaN        NaN   NaN    NaN
# 1990-10-05   NaN    NaN        NaN        NaN        NaN   NaN    NaN
# ...          ...    ...        ...        ...        ...   ...    ...
# 2026-03-02  6.28  0.026  33.509998  55.980000  52.410000  12.1  15.04
# 2026-03-03  6.21  0.026  33.509998  54.119999  51.660000  12.1  14.66
# 2026-03-04  6.36  0.026  33.509998  52.799999  52.500000  12.1  14.86
# ...
